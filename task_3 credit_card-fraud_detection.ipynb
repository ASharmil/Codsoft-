# %%
import pandas as pd
import csv
data=pd.read_excel(r"C:\Users\Sahana S B\OneDrive\Documents\creditcard.xlsx")
data.to_csv(r"C:\Users\Sahana S B\OneDrive\Documents\creditcard.csv")
csv.reader(r"C:\Users\Sahana S B\OneDrive\Documents\creditcard.csv")
print(data)
# Out:
#           Time         V1         V2        V3        V4        V5        V6  \
# 0            0  -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1            0   1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2            1  -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3            1  -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4            2  -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...        ...        ...        ...       ...       ...       ...       ...
# 284802  172786 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  172787  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804  172788   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  172788  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  172792  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
# ...

# %%
import numpy as np
data.shape
# Out:
# (284807, 31)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  int64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  int64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data.drop('Time',axis=1)
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V21       V22  \
# ...

# %%
data['Class'].unique()
# Out:
# array([0, 1])

# %%
data.duplicated().any()
# Out:
# np.True_

# %%
data[data.duplicated]
# Out:
#           Time        V1        V2        V3        V4        V5        V6  \
# 33          26 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 35          26 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 113         74  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 114         74  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 115         74  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# ...        ...       ...       ...       ...       ...       ...       ...
# 282987  171288  1.912550 -0.455240 -1.750654  0.454324  2.089130  4.160019
# 283483  171627 -1.464380  1.368119  0.815992 -0.601282 -0.689115 -0.487154
# 283485  171627 -1.457978  1.378203  0.811515 -0.603760 -0.711883 -0.471672
# 284191  172233 -2.667936  3.160505 -3.355984  1.007845 -0.377397 -0.109730
# 284193  172233 -2.691642  3.123168 -3.339407  1.017018 -0.293095 -0.167054
#
# ...

# %%
data.drop_duplicates(keep='first',inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.shape
# Out:
# (283726, 31)

# %%
data.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean    94811.077600       0.005917      -0.004135       0.001613
# std     47481.047891       1.948026       1.646703       1.508682
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54204.750000      -0.915951      -0.600321      -0.889682
# 50%     84692.500000       0.020384       0.063949       0.179963
# 75%    139298.000000       1.316068       0.800283       1.026960
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.002966       0.001828      -0.001139       0.001801
# std         1.414184       1.377008       1.331931       1.227664
# min        -5.683171    -113.743307     -26.160506     -43.557242
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 283726 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    283726 non-null  int64
#  1   V1      283726 non-null  float64
#  2   V2      283726 non-null  float64
#  3   V3      283726 non-null  float64
#  4   V4      283726 non-null  float64
#  5   V5      283726 non-null  float64
#  6   V6      283726 non-null  float64
#  7   V7      283726 non-null  float64
#  8   V8      283726 non-null  float64
#  9   V9      283726 non-null  float64
#  10  V10     283726 non-null  float64
#  11  V11     283726 non-null  float64
#  12  V12     283726 non-null  float64
#  13  V13     283726 non-null  float64
#  14  V14     283726 non-null  float64
#  15  V15     283726 non-null  float64
#  16  V16     283726 non-null  float64
#  17  V17     283726 non-null  float64
#  18  V18     283726 non-null  float64
#  19  V19     283726 non-null  float64
# ...

# %%
len(data[data['Class']==0])#not fraud
# Out:
# 283253

# %%
len(data[data['Class']==1])#fraud
# Out:
# 473

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.countplot(x=data['Class'],hue=data['Class'])
x=data.drop('Class',axis=1)
y=data['Class']

# %%
import statsmodels.api as sm
x=data.drop('Class',axis=1)
y=data['Class']
x1=sm.add_constant(x)
logit_model=sm.Logit(y,x1)
res=logit_model.fit()
print(res.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.003922
#          Iterations 13
#                            Logit Regression Results
# ...
# Dep. Variable:                  Class   No. Observations:               283726
# Model:                          Logit   Df Residuals:                   283695
# Method:                           MLE   Df Model:                           30
# Date:                Wed, 26 Jun 2024   Pseudo R-squ.:                  0.6819
# Time:                        15:04:16   Log-Likelihood:                -1112.8
# converged:                       True   LL-Null:                       -3498.2
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -8.3983      0.250    -33.602      0.000      -8.888      -7.908
# ...

# %%
import scipy 
from scipy.stats import chi2
#G-statistics=-2*(log_null-log_likelihood)=-2*(-3498.2+1112.8)
chi2.pdf(4770.8,29)
# Out:
# np.float64(0.0)

# %%
#since the model is <0.05 it is significant
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
x=data.drop('Class',axis=1)
y=data['Class'].ravel()
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=22)
len(x_train),len(x_test),len(y_test),len(y_train)
# Out:
# C:\Users\Sahana S B\AppData\Local\Temp\ipykernel_16216\215903522.py:6: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y=data['Class'].ravel()
# (226980, 56746, 56746, 226980)

# %%
lreg=LogisticRegression(random_state=22)
lreg.fit(x_train,y_train.ravel())
# Out:
# C:\Users\Sahana S B\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=22)

# %%
y_predict=lreg.predict(x_test).ravel()
y_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
data.Class
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 283726, dtype: int64

# %%
lreg.score(x_test,y_test)
# Out:
# 0.9988721672012124

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_test,y_predict)
score
# Out:
# 0.9988721672012124

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_predict)
# Out:
# array([[56615,    34],
#        [   30,    67]])

# %%
tn,fp,fn,tp=confusion_matrix(y_test,y_predict).ravel()
print("TRUE POSITIVE",tp)
print("FALSE POSITIVE",fp)
print("TRUE NEG:",tn)
print("FALSE NEG:",fn)
# Out:
# TRUE POSITIVE 67
# FALSE POSITIVE 34
# TRUE NEG: 56615
# FALSE NEG: 30

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56649
#            1       0.66      0.69      0.68        97
#
#     accuracy                           1.00     56746
#    macro avg       0.83      0.85      0.84     56746
# weighted avg       1.00      1.00      1.00     56746

# %%
accuracy=tp+tn/(tp+tn+fn+fp)
print("ACCURACY {:0.2f}".format(accuracy))
# Out:
# ACCURACY 68.00

# %%
precision= tp/tp+fp
print("PRECISION {:0.2f}".format(precision))
# Out:
# PRECISION 35.00

# %%
sensitivity=tp/tp+fn
print("sensitivity {:0.2f}".format(sensitivity))
# Out:
# sensitivity 31.00

# %%
specificity=tn/tn+fp
print("Specificity {:0.2f}".format(specificity))
# Out:
# Specificity 35.00
